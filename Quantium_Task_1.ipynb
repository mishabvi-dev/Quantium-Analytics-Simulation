# %% [markdown]
# QUANTIUM TASK 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# IMPORT DATA

# %%
tran_data = pd.read_csv('transaction_data.csv')
tran_data.head()
